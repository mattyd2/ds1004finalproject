# %%
import plotly
import pandas as pd
import numpy as np
from plotly.graph_objs import *
from plotly.offline import init_notebook_mode, iplot

dist_duration = pd.read_csv("../data/mikeCTsAvgLatLonDist.csv", nrows=10000000)

# %%
dist_duration['transit_index'] = dist_duration['duration'].pow(4)/dist_duration['distance']
de_duped_dist_duration = dist_duration[dist_duration['start_censustract'] != dist_duration['end_censustract']]
grouped = de_duped_dist_duration.groupby(['start_censustract', "end_censustract"], as_index=False).mean()
grouped[['start_censustract', 'end_censustract']] = grouped[['start_censustract', 'end_censustract']].astype(int)
grouped[['start_censustract', 'end_censustract']] = grouped[['start_censustract', 'end_censustract']].astype(str)
print grouped.shape
grouped.head(1)
# Out:
# (1047543, 9)
#   start_censustract end_censustract  duration  start_lat  start_long  \
# 0           1000201         1000202       1.5  40.712864  -73.986458
#
#      end_lat   end_long  distance  transit_index
# 0  40.713606 -73.983012  0.187776      33.474593

# %%
start_CT_score = grouped.groupby('start_censustract', as_index=False).mean()
print start_CT_score.shape
start_CT_score.rename(columns = {'start_censustract':'censustract'}, inplace=True)
end_CT_score = grouped.groupby('end_censustract', as_index=False).mean()
end_CT_score.rename(columns = {'end_censustract':'censustract'}, inplace=True)
frames = [start_CT_score, end_CT_score]
merged = pd.concat(frames)
merged['text'] = 'duration: '+merged['duration'].astype(str)+'<br>distance: '+merged['distance'].astype(str)+'<br>transit index: '+merged['transit_index'].astype(str)
print merged.shape
merged.head(1)
# Out:
# (1804, 8)
# (2385, 9)
#   censustract   duration  start_lat  start_long    end_lat   end_long  \
# 0     1000201  15.864411  40.712864  -73.986458  40.672102 -73.958672
#
#    distance  transit_index                                               text
# 0  4.282225   19972.129189  duration: 15.864410704<br>distance: 4.28222462...

# %%
censusdata = pd.read_csv('../data/census_data/documents-export-2016-05-10/census_merged.csv', dtype=str)
censusdata = censusdata[['CT2010', 'BoroCode', 'mean_income', 'avg_travel_time']]
censusdata['censustract'] = censusdata['BoroCode']+censusdata['CT2010']
censusdata = censusdata[['BoroCode','mean_income', 'censustract', 'avg_travel_time']]
censusdata['BoroCode'] = censusdata.BoroCode.map({'1':"Manhattan", '2':"Bronx", '3':"Brooklyn", '4':"Queens", '5':"Staten Island"})
censusdata.head(2)
# Out:
#   BoroCode mean_income censustract avg_travel_time
# 0    Bronx         NaN     2000100             NaN
# 1    Bronx       75015     2000200   45.0026315789

# %%
cen_merged = merged.merge(censusdata, how='left', on='censustract')
cen_merged['mean_income'].astype(float)
cen_merged['mean_income'].astype(float)
newf = cen_merged.pivot(columns='BoroCode')
newf.columns = ['_'.join(col).strip() for col in newf.columns.values]

# %%
iplot({
    'data': [
        Scatter(x=newf['distance_'+borough],
                y=newf['transit_index_'+borough],
                text=newf['text_'+borough],
                marker=Marker(size=newf['duration_'+borough], sizemode='area', sizeref=5,),
                mode='markers', name=borough) 
                for borough in ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island']
    ],
    'layout': Layout(xaxis=XAxis(title='Distance'), yaxis=YAxis(title='Transit Index'))
}, show_link=False)
# Out:
# <div id="30d8e86a-a7d7-4450-b8a3-a77c8ddd3aed" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("30d8e86a-a7d7-4450-b8a3-a77c8ddd3aed", [{"name": "Bronx", "text": [null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null
: 19.4383206295<br>distance: 10.3009622261<br>transit index: 18562.6778205", "duration: 22.5077985411<br>distance: 12.0021088169<br>transit index: 27505.3024139", "duration: 23.3077985411<br>distance: 11.6524784068<br>transit index: 31801.5359698", "duration: 20.6411318744<br>distance: 11.896765533<br>transit index: 20152.3934732", "duration: 19.8077985411<br>distance: 11.838294625<br>transit index: 17534.7270413", "duration: 17.8296000328<br>distance: 10.1558358763<br>transit index: 14025.3537122", "duration: 19.3077985411<br>distance: 11.749600195<br>transit index: 16110.1797426",  ...

# %%
cen_merged.head(1)
# Out:
#   censustract   duration  start_lat  start_long    end_lat   end_long  \
# 0     1000201  15.864411  40.712864  -73.986458  40.672102 -73.958672
#
#    distance  transit_index                                               text  \
# 0  4.282225   19972.129189  duration: 15.864410704<br>distance: 4.28222462...
#
#     BoroCode mean_income
# 0  Manhattan     36150.0

# %%
iplot(Histogram(
    x=cen_merged['duration'],
    opacity=0.75
)
distance = plotly.graph_objs.Histogram(
    x=cen_merged['distance'],
    opacity=0.75
)

transit_index = plotly.graph_objs.Histogram(
    x=cen_merged['transit_index'],
    opacity=0.75
)

data = [duration, distance, transit_index]
layout = plotly.graph_objs.Layout(
    barmode='overlay'
)
plotly.plot.iplot(data, filename = 'basic-line')
# Out:
# ---------------------------------------------------------------------------
# PlotlyLocalCredentialsError               Traceback (most recent call last)
# <ipython-input-242-cb264c8ca3b0> in <module>()
#      17     barmode='overlay'
#      18 )
# ---> 19 plotly.plotly.iplot(data, filename = 'basic-line')
#
# //anaconda/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     149     if 'auto_open' not in plot_options:
#     150         plot_options['auto_open'] = False
# --> 151     url = plot(figure_or_data, **plot_options)
#     152
#     153     if isinstance(figure_or_data, dict):
#
# //anaconda/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     239
#     240     plot_options = _plot_option_logic(plot_options)
# --> 241     res = _send_to_plotly(figure, **plot_options)
#     242     if res['error'] == '':
#     243         if plot_options['auto_open']:
#
# //anaconda/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in _send_to_plotly(figure, **plot_options)
#    1374                       cls=utils.PlotlyJSONEncoder)
#    1375     credentials = get_credentials()
# -> 1376     validate_credentials(credentials)
#    1377     username = credentials['username']
#    1378     api_key = credentials['api_key']
#
# //anaconda/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in validate_credentials(credentials)
#    1323     api_key = credentials.get('api_key')
#    1324     if not username or not api_key:
# -> 1325         raise exceptions.PlotlyLocalCredentialsError()
#    1326
#    1327
#
# PlotlyLocalCredentialsError:
# Couldn't find a 'username', 'api-key' pair for you on your local machine. To sign in temporarily (until you stop running Python), run:
# >>> import plotly.plotly as py
# >>> py.sign_in('username', 'api_key')
#
# Even better, save your credentials permanently using the 'tools' module:
# >>> import plotly.tools as tls
# >>> tls.set_credentials_file(username='username', api_key='api-key')
#
# For more help, see https://plot.ly/python.

# %%
duration = plotly.graph_objs.Histogram(
    x=cen_merged['duration'],
    opacity=0.75
)
distance = plotly.graph_objs.Histogram(
    x=cen_merged['distance'],
    opacity=0.75
)

transit_index = plotly.graph_objs.Histogram(
    x=cen_merged['transit_index'],
    opacity=0.75
)

data = [duration, distance, transit_index]
layout = plotly.graph_objs.Layout(
    barmode='overlay'
)
plotly.plot.iplot(data, filename = 'basic-line')
